# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.decomposition import LatentDirichletAllocation

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %matplotlib inline

import matplotlib.ticker as plticker

# %% [markdown]
# # Import DataFrame

# %%
drake = pd.read_csv('../01_data/drake2019.csv')

# %% [markdown]
# The caption_words list is terms used in to label song lyrics from Genius. We don't want this to get confused or take extra weight in our data

# %%
caption_words = ['Bridge', 'Chorus', 'Intro', 'Verse 1', 'Verse 2']

# %%
#remove punctuation from lyrics column 
drake['lyrics'] = drake['lyrics'].str.replace('[^\w\s]', "")
#remove caption words
drake['lyrics'] = drake['lyrics'].str.replace('|'.join(caption_words), "")
#lowercase
drake['lyrics'] = drake['lyrics'].map(lambda x: x.lower())
#word count column
drake['word_count'] = drake['lyrics'].apply(lambda x: len(x.split()))
#unique word count
drake['unique_word'] = drake['lyrics'].apply(set).apply(len)

# %% [markdown]
# Below are the top three songs with the most unique words and the most overall word count in a song.

# %%
drake.sort_values(by = "unique_word", ascending = False)[['song', 'unique_word']][:3]
# Out:
#                                            song  unique_word
# 10  Jodeci Freestyle (Ft.DennisGraham & J.Cole)           35
# 0                          Dreams Money Can Buy           28
# 5                                     Draft Day           28

# %%
drake.sort_values(by = "word_count", ascending = False)[['song', 'word_count']][:3]
# Out:
#                                            song  word_count
# 11                                Club Paradise         781
# 10  Jodeci Freestyle (Ft.DennisGraham & J.Cole)         776
# 12                    Free Spirit (Ft.RickRoss)         764

# %% [markdown]
# # Sentiment Analyzer

# %% [markdown]
# - sia_positive : Scale of 0.0 - 1.0
# - sia_negative : Scale of 0.0 - 1.0
# - sia_neutral : Scale of 0.0 - 1.0
# - sia_compound : Scale of -1.0 - 1.0

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia_table = []
for i in drake['lyrics']:
    sia_scores = {}
    sia_scores['sia_positive'] = sia.polarity_scores(i)['pos']
    sia_scores['sia_negative'] = sia.polarity_scores(i)['neg']
    sia_scores['sia_neutral'] = sia.polarity_scores(i)['neu']
    sia_scores['sia_compound'] = sia.polarity_scores(i)['compound']

    sia_table.append(sia_scores)
    
sia_table = pd.DataFrame(sia_table)
drake = pd.concat([drake, sia_table], axis = 1)

# %%
plt.figure(figsize = (10,8))
ax = plt.gca()
plt.setp(ax.get_xticklabels(), ha = "right", rotation = 20)
ax.xaxis.set_tick_params(labelbottom=True)
plt.grid('on', linestyle='--')


sns.lineplot(x = "song", y = "sia_positive", data= drake, ax= ax, label = "sia_positive", sort = False)
sns.lineplot(x = "song", y = "sia_negative", data= drake, ax= ax, label = "sia_negative", sort = False)
sns.lineplot(x = "song", y = "sia_compound", data= drake, ax= ax, label = "sia_compound", sort = False)
sns.lineplot(x = "song", y = "sia_neutral", data= drake, ax= ax, label = "sia_neutral", sort = False)


plt.legend(loc = "lower right")
plt.title("Sentiment Analysis: Care Package - Drake(2019)")
# Out:
# Text(0.5, 1.0, 'Sentiment Analysis: Care Package - Drake(2019)')

# %% [markdown]
# # Most Common Terms

# %% [markdown]
# Investigating most common single, bi-, tri-, and quad- grams used throughout the album using CountVectorizer and TfidfVectorizer.

# %%
X = drake['lyrics']

# %%
def ngramwords(vecttype, list_ngram, titlelist, list_colors):
    fig, ax = plt.subplots(nrows = 2, ncols = 4, figsize = (20,13))
    plt.subplots_adjust(hspace = 0.6)
    
    ax = ax.ravel()
    for i, vectorizer in enumerate(vecttype):
        vec = vectorizer(ngram_range = list_ngram[i])
        words_df = pd.DataFrame(vec.fit_transform(X).todense(), columns = vec.get_feature_names())
        top_10 = words_df.sum().sort_values(ascending = True).tail(10)
        top_10.plot.bar(ax = ax[i], color = list_colors[i])
        plt.setp(ax[i].get_xticklabels(), ha = "right", rotation = 45)
        
    for i, title in enumerate(titlelist):
        ax[i].set_title(title)

# %%
ngramwords([CountVectorizer, CountVectorizer, CountVectorizer,CountVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer],
          [(1,1), (2,2), (3,3), (4,4), (1,1), (2,2), (3,3), (4,4)],
          ['CountVectorizer - (1,1)', 'CountVectorizer - (2,2)', 'CountVectorizer - (3,3)', 'CountVectorizer - (4,4)',
          'TfidfVectorizer - (1,1)', 'TfidfVectorizer - (2,2)', 'TfidfVectorizer - (3,3)', 'TfidfVectorizer - (4,4)'],
          ['rebeccapurple', 'rebeccapurple', 'rebeccapurple', 'rebeccapurple', 'darkred', 'darkred', 'darkred', 'darkred'])

# %% [markdown]
# # LDA = Topic Modeling

# %%
tfidf = TfidfVectorizer(ngram_range = (2,3), token_pattern='\w+|\$[\d\.]+|\S+')
drake_tf = tfidf.fit_transform(X).toarray()
drake_featurenames = tfidf.get_feature_names()

# %%
lda_model = LatentDirichletAllocation(n_components=5, random_state = 77
                                     )
#fit model to lyrics
lda_model.fit(drake_tf)

def display_topics(model, feature_names, no_top_words):
    topic_dict ={}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict['Topic %d words' % (topic_idx)] = ['{}'.format(feature_names[i])
                                                     for i in topic.argsort()[:-no_top_words - 1: -1]]
        topic_dict['Topic %d weights' % (topic_idx)] = ['{:.1f}'.format(topic[i])
                                                       for i in topic.argsort()[:-no_top_words -1 : -1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 4
display_topics(lda_model, drake_featurenames, no_top_words)
# Out:
#       Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights  \
# 0        the motion             0.5      i had to             0.4
# 1   just the motion             0.5    know i had             0.4
# 2    thats just the             0.5     do it for             0.4
# 3  guess thats just             0.5        it for             0.4
#
#        Topic 2 words Topic 2 weights Topic 3 words Topic 3 weights  \
# 0          right now             0.5   say my name             0.6
# 1       wouldve came             0.5        say my             0.6
# 2  wouldve came back             0.5         oh oh             0.6
# 3          came back             0.5  with me dont             0.6
#
#   Topic 4 words Topic 4 weights
# 0         can i             0.6
# 1    can i baby             0.5
# 2        i baby             0.5
# 3    baby can i             0.4

# %%
drake.to_csv('../01_data/drake_eda.csv', index  = False)
