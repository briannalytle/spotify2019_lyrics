# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.decomposition import LatentDirichletAllocation

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %matplotlib inline

# %% [markdown]
# # Import DataFrame

# %%
post = pd.read_csv('../01_data/post2019.csv')

# %% [markdown]
# The caption_words list is terms used in to label song lyrics from Genius. We don't want this to get confused or take extra weight in our data

# %%
caption_words = ['Bridge',  'Chorus', 'Intro', 
                'Verse 1', 'Verse 2']

# %%
#remove punctuation from lyrics column 
post['lyrics'] = post['lyrics'].str.replace('[^\w\s]', "")
#remove caption words
post['lyrics'] = post['lyrics'].str.replace('|'.join(caption_words), "")
#lowercase
post['lyrics'] = post['lyrics'].map(lambda x: x.lower())
#word count column
post['word_count'] = post['lyrics'].apply(lambda x: len(x.split()))
#unique word count
post['unique_word'] = post['lyrics'].apply(set).apply(len)

# %% [markdown]
# Below are the top three songs with the most unique words and the most overall word count in a song.

# %%
post.sort_values(by = "unique_word", ascending = False)[['song', 'unique_word']][:3]
# Out:
#                                    song  unique_word
# 6       Die For Me (Ft.Future & Halsey)           33
# 7   On the Road (Ft.LilBaby & MeekMill)           32
# 16                                 Wow.           30

# %%
post.sort_values(by = "word_count", ascending = False)[['song', 'word_count']][:3]
# Out:
#                                   song  word_count
# 6      Die For Me (Ft.Future & Halsey)         955
# 7  On the Road (Ft.LilBaby & MeekMill)         755
# 2                  Enemies (Ft.DaBaby)         636

# %% [markdown]
# # Sentiment Analyzer

# %% [markdown]
# - sia_positive : Scale of 0.0 - 1.0
# - sia_negative : Scale of 0.0 - 1.0
# - sia_neutral : Scale of 0.0 - 1.0
# - sia_compound : Scale of -1.0 - 1.0

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia_table = []
for i in post['lyrics']:
    sia_scores = {}
    sia_scores['sia_positive'] = sia.polarity_scores(i)['pos']
    sia_scores['sia_negative'] = sia.polarity_scores(i)['neg']
    sia_scores['sia_neutral'] = sia.polarity_scores(i)['neu']
    sia_scores['sia_compound'] = sia.polarity_scores(i)['compound']

    sia_table.append(sia_scores)
    
sia_table = pd.DataFrame(sia_table)
post = pd.concat([post, sia_table], axis = 1)

# %%
plt.figure(figsize = (10,8))
ax = plt.gca()
plt.setp(ax.get_xticklabels(), ha = "right", rotation = 20)
ax.xaxis.set_tick_params(labelbottom=True)
plt.grid('on', linestyle='--')


sns.lineplot(x = "song", y = "sia_positive", data= post, ax= ax, label = "sia_positive", sort = False)
sns.lineplot(x = "song", y = "sia_negative", data= post, ax= ax, label = "sia_negative", sort = False)
sns.lineplot(x = "song", y = "sia_compound", data= post, ax= ax, label = "sia_compound", sort = False)
sns.lineplot(x = "song", y = "sia_neutral", data= post, ax= ax, label = "sia_neutral", sort = False)


plt.legend(loc = "lower right")
plt.title("Sentiment Analysis: Hollywood's Bleeding - Post Malone(2019)")
# Out:
# Text(0.5, 1.0, "Sentiment Analysis: Hollywood's Bleeding - Post Malone(2019)")

# %% [markdown]
# # Most Common Terms

# %% [markdown]
# Investigating most common single, bi-, tri-, and quad- grams used throughout the album using CountVectorizer and TfidfVectorizer.

# %%
X = post['lyrics']

# %%
def ngramwords(vecttype, list_ngram, titlelist, list_colors):
    fig, ax = plt.subplots(nrows = 2, ncols = 4, figsize = (20,13))
    plt.subplots_adjust(hspace = 0.6)
    
    ax = ax.ravel()
    for i, vectorizer in enumerate(vecttype):
        vec = vectorizer(ngram_range = list_ngram[i])
        words_df = pd.DataFrame(vec.fit_transform(X).todense(), columns = vec.get_feature_names())
        top_10 = words_df.sum().sort_values(ascending = True).tail(10)
        top_10.plot.bar(ax = ax[i], color = list_colors[i])
        plt.setp(ax[i].get_xticklabels(), ha = "right", rotation = 45)
        
    for i, title in enumerate(titlelist):
        ax[i].set_title(title)

# %%
ngramwords([CountVectorizer, CountVectorizer, CountVectorizer,CountVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer],
          [(1,1), (2,2), (3,3), (4,4), (1,1), (2,2), (3,3), (4,4)],
          ['CountVectorizer - (1,1)', 'CountVectorizer - (2,2)', 'CountVectorizer - (3,3)', 'CountVectorizer - (4,4)',
          'TfidfVectorizer - (1,1)', 'TfidfVectorizer - (2,2)', 'TfidfVectorizer - (3,3)', 'TfidfVectorizer - (4,4)'],
          ['indigo', 'indigo', 'indigo', 'indigo', 'red', 'red', 'red', 'red'])

# %% [markdown]
# # LDA = Topic Modeling

# %%
tfidf = TfidfVectorizer(ngram_range = (2,3), token_pattern='\w+|\$[\d\.]+|\S+')
post_tf = tfidf.fit_transform(X).toarray()
post_featurenames = cvec.get_feature_names()

# %%
lda_model = LatentDirichletAllocation(n_components=5, random_state = 77
                                     )
#fit model to lyrics
lda_model.fit(post_tf)

def display_topics(model, feature_names, no_top_words):
    topic_dict ={}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict['Topic %d words' % (topic_idx)] = ['{}'.format(feature_names[i])
                                                     for i in topic.argsort()[:-no_top_words - 1: -1]]
        topic_dict['Topic %d weights' % (topic_idx)] = ['{:.1f}'.format(topic[i])
                                                       for i in topic.argsort()[:-no_top_words -1 : -1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 4
display_topics(lda_model, post_featurenames, no_top_words)
# Out:
#      Topic 0 words Topic 0 weights  Topic 1 words Topic 1 weights  \
# 0         run away             0.7        ooh ooh             0.5
# 1         youd die             0.5    ooh ooh ooh             0.5
# 2         you lied             0.5          to me             0.4
# 3  goodbye goodbye             0.5  the sunflower             0.4
#
#   Topic 2 words Topic 2 weights Topic 3 words Topic 3 weights  Topic 4 words  \
# 0        i want             0.5         oh oh             0.2      long time
# 1        til im             0.5        i cant             0.2         a long
# 2   what i want             0.5         and i             0.2    a long time
# 3       im gone             0.5       cause i             0.2  take what you
#
#   Topic 4 weights
# 0             0.6
# 1             0.6
# 2             0.6
# 3             0.5

# %%
post.to_csv('../01_data/post_eda.csv', index = False)
