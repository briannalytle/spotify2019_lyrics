# %%
import pandas as pd
import numpy as np
import json
import requests
import settings

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common import exceptions

# %%
token = 'Bearer ' + settings.access_token
base_url = "http://api.genius.com"
headers = {'Authorization': token}

# %% [markdown]
# # Post

# %%
url = 'https://genius.com/albums/Post-malone/Hollywoods-bleeding'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
track_list = soup.find_all('div', {'class' : 'chart_row-content'})
songs = []

for track in track_list:
    album = {}
    song = track.find('h3').text.strip().split('\n').pop(0)
    album['song']= song.replace('\xa0', '')
    songs.append(album)
    album['link'] = track.find('a').attrs['href']
    
    post = pd.DataFrame(songs)

album_lyrics = []
def get_url(url):
    song_lyrics = {}
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    [h.extract() for h in html('script')]
    lyrics = html.find('div', class_ = 'lyrics').get_text().strip().split("\n")
    
    #need to figure out how to remove bad chars

    song_lyrics['lyrics'] = lyrics
    album_lyrics.append(song_lyrics)
    
for links in post['link']:
    get_url(links)

# %%
post_album = pd.DataFrame(album_lyrics)
post2019 = pd.concat([post, post_album], axis = 1)
post2019.to_csv('data/post2019.csv', index = False)
post2019
# Out:
#                                                  song  \
# 0                                Hollywood's Bleeding
# 1                                        Saint-Tropez
# 2                                 Enemies (Ft.DaBaby)
# 3                                            Allergic
# 4                                A Thousand Bad Times
# 5                                             Circles
# 6                     Die For Me (Ft.Future & Halsey)
# 7                 On the Road (Ft.LilBaby & MeekMill)
# 8   Take What You Want (Ft.OzzyOsbourne & TravisSc...
# 9                                        I'm Gonna Be
# 10                        Staring at the Sun (Ft.SZA)
# 11                  Sunflower byPostMalone & Swae Lee
# 12                                           Internet
# 13                            Goodbyes (Ft.YoungThug)
# 14                                             Myself
# 15                                             I Know
# 16                                               Wow.
#
#                                                  link  \
# 0   https://genius.com/Post-malone-hollywoods-blee...
# 1   https://genius.com/Post-malone-saint-tropez-ly...
# 2       https://genius.com/Post-malone-enemies-lyrics
# 3      https://genius.com/Post-malone-allergic-lyrics
# 4   https://genius.com/Post-malone-a-thousand-bad-...
# 5       https://genius.com/Post-malone-circles-lyrics
# 6    https://genius.com/Post-malone-die-for-me-lyrics
# 7   https://genius.com/Post-malone-on-the-road-lyrics
# 8   https://genius.com/Post-malone-take-what-you-w...
# 9   https://genius.com/Post-malone-im-gonna-be-lyrics
# 10  https://genius.com/Post-malone-staring-at-the-...
# 11  https://genius.com/Post-malone-and-swae-lee-su...
# 12     https://genius.com/Post-malone-internet-lyrics
# 13     https://genius.com/Post-malone-goodbyes-lyrics
# 14       https://genius.com/Post-malone-myself-lyrics
# 15       https://genius.com/Post-malone-i-know-lyrics
# 16          https://genius.com/Post-malone-wow-lyrics
#
#                                                lyrics
# 0   [[Intro], Hollywood's bleeding, vampires feedi...
# 1   [[Intro], Ooh, yeah, yeah, hey, , [Chorus], Su...
# 2   [[Chorus: Post Malone], Used to have friends, ...
# 3   [[Verse 1], Wasted on Sunday, Erase you on Mon...
# 4   [[Intro], Yeah, oh, whoa, ooh, Yeah, yeah, , [...
# 5   [[Intro], Oh, oh, oh, Oh,  oh, oh, Oh,  oh, oh...
# 6   [[Intro: Future & Post Malone], Oh yeah, oh ye...
# 7   [[Intro: Post Malone], Mm, mm, mm, Mm, , [Chor...
# 8   [[Intro: Post Malone], Oh, , [Chorus: Ozzy Osb...
# 9   [[Intro], Can you feel it?, Can you feel it?, ...
# 10  [[Intro: Post Malone], Oh, , [Verse 1: Post Ma...
# 11  [[Intro: Swae Lee], Ayy, ayy, ayy, ayy (Ooh), ...
# 12  [[Intro], E-yeah-yeah-yeah (Oh), Whoa, E-yeah-...
# 13  [[Verse 1: Post Malone], Me and Kurt feel the ...
# 14  [[Intro], (I wish I could've been there myself...
# 15  [[Verse 1], Our love will never be another, Yo...
# 16  [[Verse 1], Said she tired of little money, ne...

# %% [markdown]
# # Billie

# %%
url = 'https://genius.com/albums/Billie-eilish/When-we-all-fall-asleep-where-do-we-go'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
track_list = soup.find_all('div', {'class' : 'chart_row-content'})
songs = []

for track in track_list:
    album = {}
    song = track.find('h3').text.strip().split('\n').pop(0)
    album['song']= song.replace('\xa0', '')
    songs.append(album)
    album['link'] = track.find('a').attrs['href']
    
    billie = pd.DataFrame(songs)

album_lyrics = []
def get_url(url):
    song_lyrics = {}
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    [h.extract() for h in html('script')]
    lyrics = html.find('div', class_ = 'lyrics').get_text().strip().split("\n")
    
    #need to figure out how to remove bad chars

    song_lyrics['lyrics'] = lyrics
    album_lyrics.append(song_lyrics)
    
for links in billie['link']:
    get_url(links)

# %%
billie_album = pd.DataFrame(album_lyrics)
billie2019 = pd.concat([billie, billie_album], axis = 1)
billie2019.to_csv('data/billie2019.csv', index = False)
billie2019
# Out:
#                               song  \
# 0                          !!!!!!!
# 1                         ​bad guy
# 2                           ​xanny
# 3    ​you should see me in a crown
# 4   ​all the good girls go to hell
# 5               ​wish you were gay
# 6           ​when the party's over
# 7                                8
# 8            ​my strange addiction
# 9                   ​bury a friend
# 10                        ​ilomilo
# 11             ​listen before i go
# 12                     ​i love you
# 13                        ​goodbye
#
#                                                  link  \
# 0            https://genius.com/Billie-eilish--lyrics
# 1     https://genius.com/Billie-eilish-bad-guy-lyrics
# 2       https://genius.com/Billie-eilish-xanny-lyrics
# 3   https://genius.com/Billie-eilish-you-should-se...
# 4   https://genius.com/Billie-eilish-all-the-good-...
# 5   https://genius.com/Billie-eilish-wish-you-were...
# 6   https://genius.com/Billie-eilish-when-the-part...
# 7           https://genius.com/Billie-eilish-8-lyrics
# 8   https://genius.com/Billie-eilish-my-strange-ad...
# 9   https://genius.com/Billie-eilish-bury-a-friend...
# 10    https://genius.com/Billie-eilish-ilomilo-lyrics
# 11  https://genius.com/Billie-eilish-listen-before...
# 12  https://genius.com/Billie-eilish-i-love-you-ly...
# 13    https://genius.com/Billie-eilish-goodbye-lyrics
#
#                                                lyrics
# 0   [[Spoken: Billie Eilish & FINNEAS], My Invisal...
# 1   [[Verse 1], White shirt now red, my bloody nos...
# 2   [[Verse 1], What is it about them?, I must be ...
# 3   [[Verse 1], Bite my tongue, bide my time, Wear...
# 4   [[Intro], My Lucifer is lonely, , [Verse 1], S...
# 5   [[Verse 1], "Baby, I don't feel so good," six ...
# 6   [[Verse 1], Don't you know I'm no good for you...
# 7   [[Verse 1], Wait a minute, let me finish, I kn...
# 8   [[Intro], No, Billy, I haven't done that dance...
# 9   [[Intro: Mehki Raine], Billie, , [Chorus: Bill...
# 10  [[Verse 1], Told you not to worry, But maybe t...
# 11  [[Verse 1], Take me to the rooftop, I wanna se...
# 12  [[Verse 1], It's not true, Tell me I’ve been l...
# 13  [[Intro], Please, please, Don't leave﻿ me, Be,...

# %% [markdown]
# # Ariana

# %%
url = 'https://genius.com/albums/Ariana-grande/Thank-u-next'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
track_list = soup.find_all('div', {'class' : 'chart_row-content'})
songs = []

for track in track_list:
    album = {}
    song = track.find('h3').text.strip().split('\n').pop(0)
    album['song']= song.replace('\xa0', '')
    songs.append(album)
    album['link'] = track.find('a').attrs['href']
    
    ariana = pd.DataFrame(songs)

album_lyrics = []
def get_url(url):
    song_lyrics = {}
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    [h.extract() for h in html('script')]
    lyrics = html.find('div', class_ = 'lyrics').get_text().strip().split("\n")
    
    #need to figure out how to remove bad chars

    song_lyrics['lyrics'] = lyrics
    album_lyrics.append(song_lyrics)
    
for links in ariana['link']:
    get_url(links)

# %%
ariana_album = pd.DataFrame(album_lyrics)
ariana2019 = pd.concat([ariana, ariana_album], axis = 1)
ariana2019.to_csv('data/ariana2019.csv', index = False)
ariana2019
# Out:
#                                          song  \
# 0                                    ​imagine
# 1                                      ​needy
# 2                                        NASA
# 3                                  ​bloodline
# 4                                 ​fake smile
# 5                                   ​bad idea
# 6                                    ​make up
# 7                                    ​ghostin
# 8                                 ​in my head
# 9                                     7 rings
# 10                             ​thank u, next
# 11  ​break up with your girlfriend, i'm bored
#
#                                                  link  \
# 0     https://genius.com/Ariana-grande-imagine-lyrics
# 1       https://genius.com/Ariana-grande-needy-lyrics
# 2        https://genius.com/Ariana-grande-nasa-lyrics
# 3   https://genius.com/Ariana-grande-bloodline-lyrics
# 4   https://genius.com/Ariana-grande-fake-smile-ly...
# 5    https://genius.com/Ariana-grande-bad-idea-lyrics
# 6     https://genius.com/Ariana-grande-make-up-lyrics
# 7     https://genius.com/Ariana-grande-ghostin-lyrics
# 8   https://genius.com/Ariana-grande-in-my-head-ly...
# 9     https://genius.com/Ariana-grande-7-rings-lyrics
# 10  https://genius.com/Ariana-grande-thank-u-next-...
# 11  https://genius.com/Ariana-grande-break-up-with...
#
#                                                lyrics
# 0   [[Verse 1], Step up, the two of us, nobody kno...
# 1   [[Verse 1], If you take too long to hit me bac...
# 2   [[Intro: Shangela Laquifa Wadley], This is one...
# 3   [[Intro: Marjorie Grande], Because I'm trying ...
# 4   [[Intro: Wendy Rene], After laughter comes tea...
# 5   [[Verse 1], I've been outta sight, I've been w...
# 6   [[Verse 1], I like to fuck with you just to ma...
# 7   [[Verse 1], I know you hear me when I cry, I t...
# 8   [[Intro: Doug Middlebrook], Here's the thing: ...
# 9   [[Verse 1], Yeah, breakfast at Tiffany's and b...
# 10  [[Verse 1], Thought I'd end up with Sean, But ...
# 11  [[Verse 1], You got me some type of way (Hmm),...
